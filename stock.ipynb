# %% [markdown]
# <a href="https://colab.research.google.com/github/SUPERREALCODER/Stocky/blob/main/stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.parse
import pandas as pd
import pytz,os
import requests
import json ,requests
from  datetime import datetime,timedelta,time
TIME_ZONE = pytz.timezone('Asia/Kolkata')

# %%
fileUrl ='https://assets.upstox.com/market-quote/instruments/exchange/complete.csv.gz'
symboldf = pd.read_csv(fileUrl)
symboldf['expiry'] = pd.to_datetime(symboldf['expiry']).apply(lambda x: x.date())
symboldf = symboldf[symboldf.exchange == 'NSE_EQ']
symboldf
# Out:
#            instrument_key  exchange_token tradingsymbol  \
# 77     NSE_EQ|DUMMYSAN005         14747.0    011NSETEST
# 78     NSE_EQ|DUMMYSAN006         14751.0    021NSETEST
# 79     NSE_EQ|DUMMYSAN007         14753.0    031NSETEST
# 80     NSE_EQ|DUMMYSAN008         14755.0    041NSETEST
# 81     NSE_EQ|DUMMYSAN009         14758.0    051NSETEST
# ...                   ...             ...           ...
# 6717  NSE_EQ|INE358U01012         11394.0          ZOTA
# 6718  NSE_EQ|INE840M01016         29050.0         ZUARI
# 6719  NSE_EQ|INE217A01012          3827.0      ZUARIIND
# 6720  NSE_EQ|INE010B01027          7929.0     ZYDUSLIFE
# 6721  NSE_EQ|INE768C01010         17635.0     ZYDUSWELL
#
#                           name  last_price expiry  strike  tick_size  \
# 77                  011NSETEST         NaN    NaN     NaN       0.05
# 78                  021NSETEST         NaN    NaN     NaN       0.05
# 79                  031NSETEST         NaN    NaN     NaN       0.05
# 80                  041NSETEST         NaN    NaN     NaN       0.05
# 81                  051NSETEST         NaN    NaN     NaN       0.05
# ...                        ...         ...    ...     ...        ...
# 6717  ZOTA HEALTH CARE LIMITED      467.30    NaN     NaN       0.05
# 6718  ZUARI AGRO CHEMICALS LTD      174.65    NaN     NaN       0.05
# 6719  ZUARI INDUSTRIES LIMITED      318.15    NaN     NaN       0.05
# 6720    ZYDUS LIFESCIENCES LTD     1076.00    NaN     NaN       0.05
# 6721    ZYDUS WELLNESS LIMITED     1714.45    NaN     NaN       0.05
#
#       lot_size instrument_type option_type exchange
# 77         1.0          EQUITY         NaN   NSE_EQ
# 78         1.0          EQUITY         NaN   NSE_EQ
# 79         1.0          EQUITY         NaN   NSE_EQ
# 80         1.0          EQUITY         NaN   NSE_EQ
# 81         1.0          EQUITY         NaN   NSE_EQ
# ...        ...             ...         ...      ...
# 6717       1.0          EQUITY         NaN   NSE_EQ
# 6718       1.0          EQUITY         NaN   NSE_EQ
# 6719       1.0          EQUITY         NaN   NSE_EQ
# 6720       1.0          EQUITY         NaN   NSE_EQ
# 6721       1.0          EQUITY         NaN   NSE_EQ
#
# [6645 rows x 12 columns]

# %%
eqCsv = pd.read_csv('EQUITY_L.csv')

# %%
isinList = 'NSE_EQ|' + eqCsv[' ISIN NUMBER']
isinList
# Out:
# 0       NSE_EQ|INE144J01027
# 1       NSE_EQ|INE253B01015
# 2       NSE_EQ|INE466L01038
# 3       NSE_EQ|INE748C01038
# 4       NSE_EQ|INE470A01017
#                ...
# 1939    NSE_EQ|INE358U01012
# 1940    NSE_EQ|INE840M01016
# 1941    NSE_EQ|INE217A01012
# 1942    NSE_EQ|INE010B01027
# 1943    NSE_EQ|INE768C01010
# Name:  ISIN NUMBER, Length: 1944, dtype: object

# %%
symboldf = symboldf[symboldf.instrument_key.isin(isinList)]
symboldf
# Out:
#            instrument_key  exchange_token tradingsymbol  \
# 198   NSE_EQ|INE144J01027         16921.0     20MICRONS
# 199   NSE_EQ|INE253B01015          7750.0    21STCENMGM
# 200   NSE_EQ|INE466L01038         13061.0        360ONE
# 253   NSE_EQ|INE748C01038          6232.0     3IINFOLTD
# 254   NSE_EQ|INE470A01017           474.0       3MINDIA
# ...                   ...             ...           ...
# 6717  NSE_EQ|INE358U01012         11394.0          ZOTA
# 6718  NSE_EQ|INE840M01016         29050.0         ZUARI
# 6719  NSE_EQ|INE217A01012          3827.0      ZUARIIND
# 6720  NSE_EQ|INE010B01027          7929.0     ZYDUSLIFE
# 6721  NSE_EQ|INE768C01010         17635.0     ZYDUSWELL
#
#                            name  last_price expiry  strike  tick_size  \
# 198              20 MICRONS LTD      173.30    NaT     NaN       0.05
# 199   21ST CENTURY MGMT SERVICE       44.70    NaT     NaN       0.05
# 200         360 ONE WAM LIMITED      823.70    NaT     NaN       0.05
# 253         3I INFOTECH LIMITED       38.15    NaT     NaN       0.05
# 254            3M INDIA LIMITED    30692.05    NaT     NaN       0.05
# ...                         ...         ...    ...     ...        ...
# 6717   ZOTA HEALTH CARE LIMITED      467.30    NaT     NaN       0.05
# 6718   ZUARI AGRO CHEMICALS LTD      174.65    NaT     NaN       0.05
# 6719   ZUARI INDUSTRIES LIMITED      318.15    NaT     NaN       0.05
# 6720     ZYDUS LIFESCIENCES LTD     1076.00    NaT     NaN       0.05
# 6721     ZYDUS WELLNESS LIMITED     1714.45    NaT     NaN       0.05
#
#       lot_size instrument_type option_type exchange
# 198        1.0          EQUITY         NaN   NSE_EQ
# 199        1.0          EQUITY         NaN   NSE_EQ
# 200        1.0          EQUITY         NaN   NSE_EQ
# 253        1.0          EQUITY         NaN   NSE_EQ
# 254        1.0          EQUITY         NaN   NSE_EQ
# ...        ...             ...         ...      ...
# 6717       1.0          EQUITY         NaN   NSE_EQ
# 6718       1.0          EQUITY         NaN   NSE_EQ
# 6719       1.0          EQUITY         NaN   NSE_EQ
# 6720       1.0          EQUITY         NaN   NSE_EQ
# 6721       1.0          EQUITY         NaN   NSE_EQ
#
# [1923 rows x 12 columns]

# %%
fromDate = (datetime.now(TIME_ZONE)  - timedelta(days=10000)) .strftime("%Y-%m-%d")
fromDate
# Out:
# '1997-01-09'

# %%
def getHistoricalData(symInfo):
    res = None
    try:
        parseInstrument = urllib.parse.quote(symInfo.instrument_key)
        fromDate = (datetime.now(TIME_ZONE)  - timedelta(days=1825)) .strftime("%Y-%m-%d")
        todate = datetime.now(TIME_ZONE).strftime("%Y-%m-%d")
        url = f'https://api.upstox.com/v2/historical-candle/{parseInstrument}/day/{todate}/{fromDate}'
        #print(url)

        res = requests.get(url,headers={'accept': 'application/json',},params={},timeout=5.0)
        candleRes = res.json()

        if 'data' in candleRes and 'candles' in candleRes['data'] and  candleRes['data']['candles']:
            candleData = pd.DataFrame(candleRes['data']['candles'])
            candleData.columns = ['date','open','high','low', 'close','vol','oi']
            candleData['date'] = pd.to_datetime(candleData['date']).dt.tz_convert('Asia/Kolkata')
            candleData['symbol'] = symInfo.tradingsymbol
            print(symInfo.tradingsymbol, len(candleData))
            return candleData
        else:
            print('No data',symInfo.instrument_key, candleRes)
    except :
        print(f'Error in data fetch for {symInfo.instrument_key} {res} {e}')

# %%
getHistoricalData(symboldf.iloc[1])
# Out:
# 21STCENMGM 1220
#                           date   open   high    low  close    vol  oi  \
# 0    2024-05-24 00:00:00+05:30  44.70  44.70  44.70  44.70    302   0
# 1    2024-05-23 00:00:00+05:30  43.00  43.85  43.00  43.85   4029   0
# 2    2024-05-22 00:00:00+05:30  42.70  43.55  42.70  43.00  13281   0
# 3    2024-05-21 00:00:00+05:30  43.55  43.60  43.55  43.55  17652   0
# 4    2024-05-18 00:00:00+05:30  44.40  44.40  44.40  44.40     30   0
# ...                        ...    ...    ...    ...    ...    ...  ..
# 1215 2019-06-04 00:00:00+05:30  18.70  19.05  18.35  18.35    496   0
# 1216 2019-06-03 00:00:00+05:30  19.05  19.05  18.70  18.70   1390   0
# 1217 2019-05-31 00:00:00+05:30  19.05  19.05  19.05  19.05     40   0
# 1218 2019-05-30 00:00:00+05:30  19.05  19.05  19.05  19.05    186   0
# 1219 2019-05-29 00:00:00+05:30  19.05  19.05  19.05  19.05     59   0
#
#           symbol
# 0     21STCENMGM
# 1     21STCENMGM
# 2     21STCENMGM
# 3     21STCENMGM
# 4     21STCENMGM
# ...          ...
# 1215  21STCENMGM
# 1216  21STCENMGM
# 1217  21STCENMGM
# 1218  21STCENMGM
# 1219  21STCENMGM
#
# [1220 rows x 8 columns]

# %%
candledfList = []
for i in symboldf.index[:100]:
    res = getHistoricalData(symboldf.loc[i])
    if res is not None: candledfList.append(res)
# Out:
# 20MICRONS 1238
# 21STCENMGM 1220
# 360ONE 1162
# 3IINFOLTD 642
# 3MINDIA 1238
# 3PLAND 1164
# 5PAISA 1238
# 63MOONS 1238
# A2ZINFRA 1238
# AAATECH 438
# AAKASH 906
# AAREYDRUGS 694
# AARON 879
# AARTECH 218
# AARTIDRUGS 1238
# AARTIIND 1238
# AARTIPHARM 326
# AARTISURF 961
# AARVEEDEN 1238
# AARVI 974
# AAVAS 1238
# ABAN 1238
# ABB 1238
# ABBOTINDIA 1238
# ABCAPITAL 1238
# ABFRL 1238
# ABMINTLLTD 649
# ABSLAMC 650
# ACC 1238
# ACCELYA 1238
# ACCURACY 855
# ACE 1238
# ACEINTEG 412
# ACI 375
# ACL 260
# ACLGATI 1238
# ADANIENSOL 1238
# ADANIENT 1238
# ADANIGREEN 1238
# ADANIPORTS 1238
# ADANIPOWER 1238
# ADFFOODS 1238
# ADL 903
# ADORWELD 1238
# ADROITINFO 1207
# ADSL 1238
# ADVANIHOTR 1238
# ADVENZYMES 1238
# AEGISCHEM 1238
# AEROFLEX 181
# AETHER 490
# AFFLE 1188
# AGARIND 1238
# AGI 1238
# AGRITECH 1238
# AGROPHOS 1238
# AGSTRA 574
# AHL 351
# AHLADA 823
# AHLEAST 1238
# AHLUCONT 1238
# AIAENG 1238
# AIRAN 1238
# AIROLAM 648
# AJANTPHARM 1238
# AJMERA 1238
# AJOONI 757
# AKASH 1098
# AKG 810
# AKI 281
# AKSHAR 499
# AKSHARCHEM 1238
# AKSHOPTFBR 1238
# AKZOINDIA 1238
# ALANKIT 1238
# ALBERTDAVD 1238
# ALEMBICLTD 1238
# ALICON 1238
# ALKALI 1238
# ALKEM 1238
# ALKYLAMINE 1238
# ALLCARGO 1238
# ALLSEC 1238
# ALMONDZ 1221
# ALOKINDS 1057
# ALPA 1238
# ALPHAGEO 1238
# ALPSINDUS 1167
# AMBER 1238
# AMBICAAGAR 768
# AMBIKCO 1238
# AMBUJACEM 1238
# AMDIND 1238
# AMIORG 669
# AMJLAND 1238
# AMNPLST 133
# AMRUTANJAN 1238
# ANANDRATHI 607
# ANANTRAJ 1238
# ANDHRAPAP 1237

# %%
finalDataDf = pd.concat(candledfList,ignore_index= True)
finalDataDf
# Out:
#                             date    open    high     low   close      vol  oi  \
# 0      2024-05-24 00:00:00+05:30  177.50  181.85  172.50  173.30   180249   0
# 1      2024-05-23 00:00:00+05:30  181.00  182.90  176.00  176.60    99783   0
# 2      2024-05-22 00:00:00+05:30  182.00  183.95  177.95  179.35   156142   0
# 3      2024-05-21 00:00:00+05:30  190.00  192.00  181.00  182.20   315192   0
# 4      2024-05-18 00:00:00+05:30  195.00  195.00  185.55  187.90   185033   0
# ...                          ...     ...     ...     ...     ...      ...  ..
# 103729 2019-06-04 00:00:00+05:30  423.00  423.00  420.20  420.60   122372   0
# 103730 2019-06-03 00:00:00+05:30  424.25  425.05  421.05  422.55   115775   0
# 103731 2019-05-31 00:00:00+05:30  421.05  427.40  421.05  426.55   403755   0
# 103732 2019-05-30 00:00:00+05:30  425.00  425.00  408.70  423.40  1388178   0
# 103733 2019-05-29 00:00:00+05:30  429.55  439.00  425.00  427.90    46581   0
#
#            symbol
# 0       20MICRONS
# 1       20MICRONS
# 2       20MICRONS
# 3       20MICRONS
# 4       20MICRONS
# ...           ...
# 103729  ANDHRAPAP
# 103730  ANDHRAPAP
# 103731  ANDHRAPAP
# 103732  ANDHRAPAP
# 103733  ANDHRAPAP
#
# [103734 rows x 8 columns]

# %%
isCsv = True
for symData in candledfList:
    try:
        filename = symData.iloc[0]['symbol']
        if isCsv :
            filename = f'{filename}.csv'
            symData.to_csv(filename,index=False)
        else:
            filename = f'{filename}.parquet'
            symData.to_parquet(filename , engine='pyarrow')
    except Exception as e:
        print(f'Error {e}')
